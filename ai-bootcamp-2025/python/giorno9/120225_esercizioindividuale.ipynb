# %% [markdown]
# **12_02_25 Esercizio individuale**

# %% [markdown]
# *Importare le librerie*

# %%
# !pip install ipytest
# Out:
# Collecting ipytest
#   Downloading ipytest-0.14.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipytest) (8.32.0)
# Requirement already satisfied: packaging in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipytest) (24.2)
# Requirement already satisfied: pytest>=5.4 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipytest) (8.3.4)
# Requirement already satisfied: colorama in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from pytest>=5.4->ipytest) (0.4.6)
# Requirement already satisfied: iniconfig in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from pytest>=5.4->ipytest) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from pytest>=5.4->ipytest) (1.5.0)
# Requirement already satisfied: decorator in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from ipython->ipytest) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from jedi>=0.16->ipython->ipytest) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipytest) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from stack_data->ipython->ipytest) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from stack_data->ipython->ipytest) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\giuli\pycharmprojects\class-bootcamp-jupyter\.env\lib\site-packages (from stack_data->ipython->ipytest) (0.2.3)
# Downloading ipytest-0.14.2-py3-none-any.whl (18 kB)
# Installing collected packages: ipytest
# Successfully installed ipytest-0.14.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import ipytest

# %%
ipytest.autoconfig()

# %% [markdown]
# *Caricamento del dataset*

# %%
df = pd.read_csv('HollywoodMovies.csv')

# %% [markdown]
# *Visualizzare le prime righe*

# %%
display(df.head())
# Out:
#                                        Movie   LeadStudio  RottenTomatoes  \
# 0                               Spider-Man 3         Sony            61.0
# 1                            Shrek the Third    Paramount            42.0
# 2                               Transformers    Paramount            57.0
# 3   Pirates of the Caribbean: At World's End       Disney            45.0
# 4  Harry Potter and the Order of the Phoenix  Warner Bros            78.0
#
#    AudienceScore          Story      Genre  TheatersOpenWeek  OpeningWeekend  \
# 0           54.0  Metamorphosis     Action            4252.0           151.1
# 1           57.0          Quest  Animation            4122.0           121.6
# 2           89.0  Monster Force     Action            4011.0            70.5
# 3           74.0         Rescue     Action            4362.0           114.7
# 4           82.0          Quest  Adventure            4285.0            77.1
#
#    BOAvgOpenWeekend  DomesticGross  ForeignGross  WorldGross  Budget  \
# 0           35540.0         336.53        554.34      890.87   258.0
# 1           29507.0         322.72        476.24      798.96   160.0
# 2           17577.0         319.25        390.46      709.71   150.0
# 3           26302.0         309.42        654.00      963.42   300.0
# 4           17998.0         292.00        647.88      939.89   150.0
#
#    Profitability  OpenProfit  Year
# 0         345.30       58.57  2007
# 1         499.35       76.00  2007
# 2         473.14       47.00  2007
# 3         321.14       38.23  2007
# 4         626.59       51.40  2007

# %% [markdown]
# *Informazioni generali sul dataset*

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 970 entries, 0 to 969
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Movie             970 non-null    object
#  1   LeadStudio        961 non-null    object
#  2   RottenTomatoes    913 non-null    float64
#  3   AudienceScore     907 non-null    float64
#  4   Story             641 non-null    object
#  5   Genre             691 non-null    object
#  6   TheatersOpenWeek  949 non-null    float64
#  7   OpeningWeekend    969 non-null    float64
#  8   BOAvgOpenWeekend  945 non-null    float64
#  9   DomesticGross     970 non-null    float64
#  10  ForeignGross      876 non-null    float64
#  11  WorldGross        914 non-null    float64
#  12  Budget            897 non-null    float64
#  13  Profitability     896 non-null    float64
#  14  OpenProfit        895 non-null    float64
#  15  Year              970 non-null    int64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 121.4+ KB
# None

# %% [markdown]
# *1. Numero di film per anno*

# %%
movies_per_year = df['Year'].value_counts().sort_index()

# %% [markdown]
# *Grafico a barre*

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=movies_per_year.index, y=movies_per_year.values, hue=movies_per_year.index, palette='viridis', legend=False)
plt.xlabel("Anno")
plt.ylabel("Numero di film")
plt.title("Numero di film usciti per anno")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# *2. Distribuzione dei generi cinematografici*

# %%
genre_distribution = df['Genre'].value_counts()

# %% [markdown]
# *Grafico a torta*

# %%
percentuali = (genre_distribution / genre_distribution.sum() * 100).round(1)
etichette = [f"{genere} ({perc}%)" for genere, perc in zip(genre_distribution.index, percentuali)]

plt.figure(figsize=(8, 8))
wedges, texts = plt.pie(genre_distribution, startangle=140)

plt.legend(wedges, etichette, title="Generi", loc="center left", bbox_to_anchor=(1, 0.5))
plt.title('Distribuzione dei generi cinematografici')
plt.show()

# %% [markdown]
# *3. Grafico a dispersione per la relazione tra budget e incassi mondiali*

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Budget'], y=df['WorldGross'], hue=df['Genre'], palette='Set2', alpha=0.7, s=80)
sns.regplot(x=df['Budget'], y=df['WorldGross'], scatter=False, color='black', line_kws={"linestyle": "dashed"})
plt.xscale('log')
plt.yscale('log')
plt.title('Relazione tra budget e incassi mondiali')
plt.xlabel('Budget (in milioni di dollari)')
plt.ylabel('Incassi mondiali (in milioni di dollari)')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()

# %% [markdown]
# **Bonus**

# %% [markdown]
# *TDD*

# %% [markdown]
# *Funzioni per testare il numero di film per anno e la distribuzione dei generi*

# %%
def test_movies_per_year():
    df = pd.read_csv('HollywoodMovies.csv')
    movies_per_year = df['Year'].value_counts().sort_index()

    assert movies_per_year.sum() == len(df), "La somma dei film per anno non corrisponde al numero totale di film nel DataFrame"
    assert movies_per_year.index.is_monotonic_increasing, "Gli anni non sono ordinati correttamente"

def test_genre_distribution():
    df = pd.read_csv('HollywoodMovies.csv')
    genre_distribution = df['Genre'].dropna().value_counts()
    assert genre_distribution.sum() == len(df) - df['Genre'].isna().sum()
    assert (genre_distribution > 0).all()
    percentuali = (genre_distribution / genre_distribution.sum() * 100).round(1)
    assert all(percentuali >= 0)

ipytest.run()
# Out:
# ..                                                                                           [100%]
# 2 passed in 0.02s
# <ExitCode.OK: 0>
